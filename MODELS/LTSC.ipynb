# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import os, random, numpy as np, tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)
os.environ['PYTHONHASHSEED'] = '42'

# %%
df=pd.read_csv("C:/Users/Dhruv/Onedrive/Desktop/samsung/aqi/delhi_ncr_aqi_dataset.csv")
df
# Out:
#                    datetime        date  year  month  day  hour day_of_week  \
# 0       2020-01-01 06:00:00  2020-01-01  2020      1    1     6   Wednesday
# 1       2020-01-01 12:00:00  2020-01-01  2020      1    1    12   Wednesday
# 2       2020-01-01 18:00:00  2020-01-01  2020      1    1    18   Wednesday
# 3       2020-01-01 23:00:00  2020-01-01  2020      1    1    23   Wednesday
# 4       2020-01-01 06:00:00  2020-01-01  2020      1    1     6   Wednesday
# ...                     ...         ...   ...    ...  ...   ...         ...
# 201659  2025-12-31 23:00:00  2025-12-31  2025     12   31    23   Wednesday
# 201660  2025-12-31 06:00:00  2025-12-31  2025     12   31     6   Wednesday
# 201661  2025-12-31 12:00:00  2025-12-31  2025     12   31    12   Wednesday
# 201662  2025-12-31 18:00:00  2025-12-31  2025     12   31    18   Wednesday
# 201663  2025-12-31 23:00:00  2025-12-31  2025     12   31    23   Wednesday
#
#         is_weekend  season       city  ...    no2   so2    co    o3  \
# 0                0  winter      Delhi  ...  119.6  47.7  5.19  12.3
# 1                0  winter      Delhi  ...  117.9  39.3  4.32  15.8
# 2                0  winter      Delhi  ...  150.1  36.3  7.13  14.3
# 3                0  winter      Delhi  ...  142.0  30.3  4.90  13.2
# 4                0  winter      Delhi  ...  138.4  41.5  7.56  15.4
# ...            ...     ...        ...  ...    ...   ...   ...   ...
# 201659           0  winter  Ghaziabad  ...   97.0  23.9  5.58  14.8
# 201660           0  winter  Ghaziabad  ...  119.2  26.9  5.34  12.1
# 201661           0  winter  Ghaziabad  ...   90.3  33.7  3.73  28.2
# 201662           0  winter  Ghaziabad  ...  170.7  20.9  6.98  22.9
# 201663           0  winter  Ghaziabad  ...   89.0  27.5  5.17  17.6
#
#         temperature  humidity  wind_speed  visibility  aqi  aqi_category
# 0               9.4       100         3.6         1.2  500        Severe
# 1              20.6        50         5.9         1.4  500        Severe
# 2              12.4        56         4.5         1.1  500        Severe
# 3              14.4        48         5.8         1.4  500        Severe
# 4               6.8       100         2.8         0.4  500        Severe
# ...             ...       ...         ...         ...  ...           ...
# 201659         16.1        51         3.8         0.9  500        Severe
# 201660          9.8        95         3.2         1.2  500        Severe
# 201661         21.4        57         7.1         2.9  500        Severe
# 201662         15.4        51         6.8         1.2  500        Severe
# 201663         17.3        46         5.4         1.0  500        Severe
#
# [201664 rows x 25 columns]

# %%
df['station'].unique()
# Out:
# array(['Anand Vihar, Delhi', 'Jahangirpuri, Delhi', 'Wazirpur, Delhi',
#        'Bawana, Delhi', 'ITO, Delhi', 'Punjabi Bagh, Delhi',
#        'Okhla Phase 2, Delhi', 'Shadipur, Delhi', 'Rohini, Delhi',
#        'RK Puram, Delhi', 'Siri Fort, Delhi', 'Dwarka Sec 8, Delhi',
#        'NSIT Dwarka, Delhi', 'Mandir Marg, Delhi', 'Noida Sec 62',
#        'Noida Sec 125', 'Greater Noida', 'Gurugram Vikas Sadan',
#        'Gurugram Sec 51', 'Faridabad Sec 16A', 'Faridabad New Town',
#        'Ghaziabad Vasundhara', 'Ghaziabad Loni'], dtype=object)

# %%
df.columns
# Out:
# Index(['datetime', 'date', 'year', 'month', 'day', 'hour', 'day_of_week',
#        'is_weekend', 'season', 'city', 'station', 'latitude', 'longitude',
#        'pm25', 'pm10', 'no2', 'so2', 'co', 'o3', 'temperature', 'humidity',
#        'wind_speed', 'visibility', 'aqi', 'aqi_category'],
#       dtype='object')

# %%
df = df.sort_values('datetime').reset_index(drop=True)
df2=df.copy()

# %%
df=df[['year', 'month', 'day', 'hour',
       'is_weekend','season', 'station', 'aqi']]

# %%
df
# Out:
#         year  month  day  hour  is_weekend  season              station  aqi
# 0       2020      1    1     6           0  winter   Anand Vihar, Delhi  500
# 1       2020      1    1     6           0  winter   Mandir Marg, Delhi  399
# 2       2020      1    1     6           0  winter   NSIT Dwarka, Delhi  500
# 3       2020      1    1     6           0  winter        Noida Sec 125  500
# 4       2020      1    1     6           0  winter  Dwarka Sec 8, Delhi  473
# ...      ...    ...  ...   ...         ...     ...                  ...  ...
# 201659  2025     12   31    23           0  winter         Noida Sec 62  500
# 201660  2025     12   31    23           0  winter        Noida Sec 125  489
# 201661  2025     12   31    23           0  winter        Greater Noida  500
# 201662  2025     12   31    23           0  winter      Wazirpur, Delhi  500
# 201663  2025     12   31    23           0  winter       Ghaziabad Loni  500
#
# [201664 rows x 8 columns]

# %%
df['station'].unique()
# Out:
# array(['Anand Vihar, Delhi', 'Mandir Marg, Delhi', 'NSIT Dwarka, Delhi',
#        'Noida Sec 125', 'Dwarka Sec 8, Delhi', 'Greater Noida',
#        'Siri Fort, Delhi', 'RK Puram, Delhi', 'Gurugram Vikas Sadan',
#        'Rohini, Delhi', 'Gurugram Sec 51', 'Shadipur, Delhi',
#        'Okhla Phase 2, Delhi', 'Faridabad Sec 16A', 'Punjabi Bagh, Delhi',
#        'Faridabad New Town', 'Noida Sec 62', 'Wazirpur, Delhi',
#        'Ghaziabad Loni', 'Ghaziabad Vasundhara', 'ITO, Delhi',
#        'Bawana, Delhi', 'Jahangirpuri, Delhi'], dtype=object)

# %%
df1=df[df['station'] == 'NSIT Dwarka, Delhi']
df1=df1.drop(columns=['station'])
df1
# Out:
#         year  month  day  hour  is_weekend  season  aqi
# 2       2020      1    1     6           0  winter  500
# 25      2020      1    1    12           0  winter  408
# 67      2020      1    1    18           0  winter  466
# 70      2020      1    1    23           0  winter  500
# 98      2020      1    2     6           0  winter  500
# ...      ...    ...  ...   ...         ...     ...  ...
# 201565  2025     12   30    23           0  winter  500
# 201578  2025     12   31     6           0  winter  500
# 201597  2025     12   31    12           0  winter  349
# 201627  2025     12   31    18           0  winter  426
# 201657  2025     12   31    23           0  winter  500
#
# [8768 rows x 7 columns]

# %%
df1['season'].unique()
# Out:
# array(['winter', 'summer', 'monsoon', 'post_monsoon'], dtype=object)

# %%
df1 = pd.get_dummies(df1, columns=['season'], drop_first=True)

# %%
df1['aqi_lag_1']  = df1['aqi'].shift(1)   # 6 hours ago
df1['aqi_lag_2']  = df1['aqi'].shift(2)   # 12 hours ago
df1['aqi_lag_4']  = df1['aqi'].shift(4)   # 24 hours ago (daily cycle)
df1['aqi_lag_8']  = df1['aqi'].shift(8)   # 48 hours ago
df1['aqi_lag_28'] = df1['aqi'].shift(28)  # ~7 days

# %%
df1
# Out:
#         year  month  day  hour  is_weekend  aqi  season_post_monsoon  \
# 2       2020      1    1     6           0  500                False
# 25      2020      1    1    12           0  408                False
# 67      2020      1    1    18           0  466                False
# 70      2020      1    1    23           0  500                False
# 98      2020      1    2     6           0  500                False
# ...      ...    ...  ...   ...         ...  ...                  ...
# 201565  2025     12   30    23           0  500                False
# 201578  2025     12   31     6           0  500                False
# 201597  2025     12   31    12           0  349                False
# 201627  2025     12   31    18           0  426                False
# 201657  2025     12   31    23           0  500                False
#
#         season_summer  season_winter  aqi_lag_1  aqi_lag_2  aqi_lag_4  \
# 2               False           True        NaN        NaN        NaN
# 25              False           True      500.0        NaN        NaN
# 67              False           True      408.0      500.0        NaN
# 70              False           True      466.0      408.0        NaN
# 98              False           True      500.0      466.0      500.0
# ...               ...            ...        ...        ...        ...
# 201565          False           True      390.0      372.0      435.0
# 201578          False           True      500.0      390.0      500.0
# 201597          False           True      500.0      500.0      372.0
# 201627          False           True      349.0      500.0      390.0
# 201657          False           True      426.0      349.0      500.0
#
#         aqi_lag_8  aqi_lag_28
# 2             NaN         NaN
# 25            NaN         NaN
# 67            NaN         NaN
# 70            NaN         NaN
# 98            NaN         NaN
# ...           ...         ...
# 201565      389.0       500.0
# 201578      500.0       500.0
# 201597      451.0       394.0
# 201627      416.0       442.0
# 201657      435.0       454.0
#
# [8768 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# year          0
# month         0
# day           0
# hour          0
# is_weekend    0
# season        0
# station       0
# aqi           0
# dtype: int64

# %%
df1 = df1.dropna().reset_index(drop=True)

# %%
df1
# Out:
#       year  month  day  hour  is_weekend  aqi  season_post_monsoon  \
# 0     2020      1    8     6           0  500                False
# 1     2020      1    8    12           0  398                False
# 2     2020      1    8    18           0  383                False
# 3     2020      1    8    23           0  500                False
# 4     2020      1    9     6           0  500                False
# ...    ...    ...  ...   ...         ...  ...                  ...
# 8735  2025     12   30    23           0  500                False
# 8736  2025     12   31     6           0  500                False
# 8737  2025     12   31    12           0  349                False
# 8738  2025     12   31    18           0  426                False
# 8739  2025     12   31    23           0  500                False
#
#       season_summer  season_winter  aqi_lag_1  aqi_lag_2  aqi_lag_4  \
# 0             False           True      500.0      405.0      500.0
# 1             False           True      500.0      500.0      351.0
# 2             False           True      398.0      500.0      405.0
# 3             False           True      383.0      398.0      500.0
# 4             False           True      500.0      383.0      500.0
# ...             ...            ...        ...        ...        ...
# 8735          False           True      390.0      372.0      435.0
# 8736          False           True      500.0      390.0      500.0
# 8737          False           True      500.0      500.0      372.0
# 8738          False           True      349.0      500.0      390.0
# 8739          False           True      426.0      349.0      500.0
#
#       aqi_lag_8  aqi_lag_28
# 0         500.0       500.0
# 1         460.0       408.0
# 2         500.0       466.0
# 3         490.0       500.0
# 4         500.0       500.0
# ...         ...         ...
# 8735      389.0       500.0
# 8736      500.0       500.0
# 8737      451.0       394.0
# 8738      416.0       442.0
# 8739      435.0       454.0
#
# [8740 rows x 14 columns]

# %%
df1.columns
# Out:
# Index(['year', 'month', 'day', 'hour', 'is_weekend', 'aqi',
#        'season_post_monsoon', 'season_summer', 'season_winter', 'aqi_lag_1',
#        'aqi_lag_2', 'aqi_lag_4', 'aqi_lag_8', 'aqi_lag_28'],
#       dtype='object')

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# sort by time
lstm_df = df1.sort_values(['year','month','day','hour']).reset_index(drop=True)

feature_cols = [
    'year', 'month', 'day',             
    'hour', 'is_weekend',
    'season_winter', 'season_summer', 'season_post_monsoon', 'aqi_lag_1',
       'aqi_lag_2', 'aqi_lag_4', 'aqi_lag_8', 'aqi_lag_28'
]

# -----------------------------
# TRAIN / TEST SPLIT
# -----------------------------
train_df = lstm_df[lstm_df['year'] < 2025]
test_df  = lstm_df[lstm_df['year'] == 2025]

X_train = train_df[feature_cols].values
X_test  = test_df[feature_cols].values

y_train = train_df['aqi'].values.reshape(-1,1)
y_test  = test_df['aqi'].values.reshape(-1,1)

# -----------------------------
# SCALING (fit ONLY on train)
# -----------------------------
X_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = X_scaler.fit_transform(X_train)
X_test  = X_scaler.transform(X_test)

y_train = y_scaler.fit_transform(y_train)
y_test  = y_scaler.transform(y_test)

# -----------------------------
# CREATE SEQUENCES
# -----------------------------
TIMESTEPS = 24  # 1 day window

def create_sequences(X, y, t):
    X_seq, y_seq = [], []
    for i in range(len(X) - t):
        X_seq.append(X[i:i+t])
        y_seq.append(y[i+t])
    return np.array(X_seq), np.array(y_seq)

X_train_seq, y_train_seq = create_sequences(X_train, y_train, TIMESTEPS)
X_test_seq,  y_test_seq  = create_sequences(X_test,  y_test,  TIMESTEPS)

# %%
lstm_df
# Out:
#       year  month  day  hour  is_weekend  aqi  season_post_monsoon  \
# 0     2020      1    8     6           0  500                False
# 1     2020      1    8    12           0  398                False
# 2     2020      1    8    18           0  383                False
# 3     2020      1    8    23           0  500                False
# 4     2020      1    9     6           0  500                False
# ...    ...    ...  ...   ...         ...  ...                  ...
# 8735  2025     12   30    23           0  500                False
# 8736  2025     12   31     6           0  500                False
# 8737  2025     12   31    12           0  349                False
# 8738  2025     12   31    18           0  426                False
# 8739  2025     12   31    23           0  500                False
#
#       season_summer  season_winter  aqi_lag_1  aqi_lag_2  aqi_lag_4  \
# 0             False           True      500.0      405.0      500.0
# 1             False           True      500.0      500.0      351.0
# 2             False           True      398.0      500.0      405.0
# 3             False           True      383.0      398.0      500.0
# 4             False           True      500.0      383.0      500.0
# ...             ...            ...        ...        ...        ...
# 8735          False           True      390.0      372.0      435.0
# 8736          False           True      500.0      390.0      500.0
# 8737          False           True      500.0      500.0      372.0
# 8738          False           True      349.0      500.0      390.0
# 8739          False           True      426.0      349.0      500.0
#
#       aqi_lag_8  aqi_lag_28
# 0         500.0       500.0
# 1         460.0       408.0
# 2         500.0       466.0
# 3         490.0       500.0
# 4         500.0       500.0
# ...         ...         ...
# 8735      389.0       500.0
# 8736      500.0       500.0
# 8737      451.0       394.0
# 8738      416.0       442.0
# 8739      435.0       454.0
#
# [8740 rows x 14 columns]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

lstm = Sequential()
lstm.add(LSTM(64, input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])))
lstm.add(Dense(1))

lstm.compile(
    optimizer='adam',
    loss='mae',
    metrics=['mae']
)

lstm.summary()
# Out:
# C:\Users\Dhruv\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          19,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,033 (78.25 KB)
#  Trainable params: 20,033 (78.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(
    monitor='val_mae',
    patience=15,        
    min_delta=0.0015,     
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_mae',
    factor=0.5,
    patience=6,
    min_lr=1e-5,
    verbose=1
)

history = lstm.fit(
    X_train_seq,
    y_train_seq,
    epochs=120,         
    batch_size=32,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.3230 - mae: 0.3230 - val_loss: 0.2485 - val_mae: 0.2485 - learning_rate: 0.0010
# Epoch 2/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2217 - mae: 0.2217 - val_loss: 0.2693 - val_mae: 0.2693 - learning_rate: 0.0010
# Epoch 3/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.2233 - mae: 0.2233 - val_loss: 0.2097 - val_mae: 0.2097 - learning_rate: 0.0010
# Epoch 4/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1941 - mae: 0.1941 - val_loss: 0.1798 - val_mae: 0.1798 - learning_rate: 0.0010
# Epoch 5/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1700 - mae: 0.1700 - val_loss: 0.2164 - val_mae: 0.2164 - learning_rate: 0.0010
# Epoch 6/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1820 - mae: 0.1820 - val_loss: 0.1746 - val_mae: 0.1746 - learning_rate: 0.0010
# Epoch 7/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1845 - mae: 0.1845 - val_loss: 0.1685 - val_mae: 0.1685 - learning_rate: 0.0010
# Epoch 8/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.1606 - mae: 0.1606 - val_loss: 0.1584 - val_mae: 0.1584 - learning_rate: 0.0010
# Epoch 9/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1506 - mae: 0.1506 - val_loss: 0.1555 - val_mae: 0.1555 - learning_rate: 0.0010
# Epoch 10/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1682 - mae: 0.1682 - val_loss: 0.1770 - val_mae: 0.1770 - learning_rate: 0.0010
# Epoch 11/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1547 - mae: 0.1547 - val_loss: 0.1563 - val_mae: 0.1563 - learning_rate: 0.0010
# Epoch 12/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1622 - mae: 0.1622 - val_loss: 0.1601 - val_mae: 0.1601 - learning_rate: 0.0010
# Epoch 13/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1575 - mae: 0.1575 - val_loss: 0.1496 - val_mae: 0.1496 - learning_rate: 0.0010
# Epoch 14/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1634 - mae: 0.1634 - val_loss: 0.1558 - val_mae: 0.1558 - learning_rate: 0.0010
# Epoch 15/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1477 - mae: 0.1477 - val_loss: 0.1470 - val_mae: 0.1470 - learning_rate: 0.0010
# Epoch 16/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1559 - mae: 0.1559 - val_loss: 0.1630 - val_mae: 0.1630 - learning_rate: 0.0010
# Epoch 17/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1502 - mae: 0.1502 - val_loss: 0.1604 - val_mae: 0.1604 - learning_rate: 0.0010
# Epoch 18/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1581 - mae: 0.1581 - val_loss: 0.1577 - val_mae: 0.1577 - learning_rate: 0.0010
# Epoch 19/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1477 - mae: 0.1477 - val_loss: 0.1594 - val_mae: 0.1594 - learning_rate: 0.0010
# Epoch 20/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1479 - mae: 0.1479 - val_loss: 0.1693 - val_mae: 0.1693 - learning_rate: 0.0010
# Epoch 21/120
# 179/182 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1489 - mae: 0.1489
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1476 - mae: 0.1476 - val_loss: 0.1662 - val_mae: 0.1662 - learning_rate: 0.0010
# Epoch 22/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1424 - mae: 0.1424 - val_loss: 0.1459 - val_mae: 0.1459 - learning_rate: 5.0000e-04
# Epoch 23/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.1403 - mae: 0.1403 - val_loss: 0.1493 - val_mae: 0.1493 - learning_rate: 5.0000e-04
# Epoch 24/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1380 - mae: 0.1380 - val_loss: 0.1482 - val_mae: 0.1482 - learning_rate: 5.0000e-04
# Epoch 25/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1369 - mae: 0.1369 - val_loss: 0.1491 - val_mae: 0.1491 - learning_rate: 5.0000e-04
# Epoch 26/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1331 - mae: 0.1331 - val_loss: 0.1542 - val_mae: 0.1542 - learning_rate: 5.0000e-04
# Epoch 27/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1326 - mae: 0.1326 - val_loss: 0.1530 - val_mae: 0.1530 - learning_rate: 5.0000e-04
# Epoch 28/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1431 - mae: 0.1431
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1372 - mae: 0.1372 - val_loss: 0.1497 - val_mae: 0.1497 - learning_rate: 5.0000e-04
# Epoch 29/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1291 - mae: 0.1291 - val_loss: 0.1369 - val_mae: 0.1369 - learning_rate: 2.5000e-04
# Epoch 30/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1306 - mae: 0.1306 - val_loss: 0.1327 - val_mae: 0.1327 - learning_rate: 2.5000e-04
# Epoch 31/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1317 - mae: 0.1317 - val_loss: 0.1324 - val_mae: 0.1324 - learning_rate: 2.5000e-04
# Epoch 32/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1275 - mae: 0.1275 - val_loss: 0.1323 - val_mae: 0.1323 - learning_rate: 2.5000e-04
# Epoch 33/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.1269 - mae: 0.1269 - val_loss: 0.1326 - val_mae: 0.1326 - learning_rate: 2.5000e-04
# Epoch 34/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1256 - mae: 0.1256 - val_loss: 0.1340 - val_mae: 0.1340 - learning_rate: 2.5000e-04
# Epoch 35/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1249 - mae: 0.1249 - val_loss: 0.1328 - val_mae: 0.1328 - learning_rate: 2.5000e-04
# Epoch 36/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1236 - mae: 0.1236 - val_loss: 0.1329 - val_mae: 0.1329 - learning_rate: 2.5000e-04
# Epoch 37/120
# 176/182 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1327 - mae: 0.1327
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1280 - mae: 0.1280 - val_loss: 0.1399 - val_mae: 0.1399 - learning_rate: 2.5000e-04
# Epoch 38/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1226 - mae: 0.1226 - val_loss: 0.1315 - val_mae: 0.1315 - learning_rate: 1.2500e-04
# Epoch 39/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.1227 - mae: 0.1227 - val_loss: 0.1302 - val_mae: 0.1302 - learning_rate: 1.2500e-04
# Epoch 40/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.1222 - mae: 0.1222 - val_loss: 0.1301 - val_mae: 0.1301 - learning_rate: 1.2500e-04
# Epoch 41/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - loss: 0.1209 - mae: 0.1209 - val_loss: 0.1299 - val_mae: 0.1299 - learning_rate: 1.2500e-04
# Epoch 42/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.1207 - mae: 0.1207 - val_loss: 0.1298 - val_mae: 0.1298 - learning_rate: 1.2500e-04
# Epoch 43/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.1204 - mae: 0.1204 - val_loss: 0.1303 - val_mae: 0.1303 - learning_rate: 1.2500e-04
# Epoch 44/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.1198 - mae: 0.1198 - val_loss: 0.1301 - val_mae: 0.1301 - learning_rate: 1.2500e-04
# Epoch 45/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.1199 - mae: 0.1199 - val_loss: 0.1301 - val_mae: 0.1301 - learning_rate: 1.2500e-04
# Epoch 46/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.1207 - mae: 0.1207 - val_loss: 0.1312 - val_mae: 0.1312 - learning_rate: 1.2500e-04
# Epoch 47/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.1202 - mae: 0.1202 - val_loss: 0.1302 - val_mae: 0.1302 - learning_rate: 1.2500e-04
# Epoch 48/120
# 181/182 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1274 - mae: 0.1274
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.1196 - mae: 0.1196 - val_loss: 0.1312 - val_mae: 0.1312 - learning_rate: 1.2500e-04
# Epoch 49/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.1177 - mae: 0.1177 - val_loss: 0.1291 - val_mae: 0.1291 - learning_rate: 6.2500e-05
# Epoch 50/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.1175 - mae: 0.1175 - val_loss: 0.1292 - val_mae: 0.1292 - learning_rate: 6.2500e-05
# Epoch 51/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.1174 - mae: 0.1174 - val_loss: 0.1290 - val_mae: 0.1290 - learning_rate: 6.2500e-05
# Epoch 52/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.1171 - mae: 0.1171 - val_loss: 0.1290 - val_mae: 0.1290 - learning_rate: 6.2500e-05
# Epoch 53/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.1169 - mae: 0.1169 - val_loss: 0.1291 - val_mae: 0.1291 - learning_rate: 6.2500e-05
# Epoch 54/120
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.1167 - mae: 0.1167 - val_loss: 0.1291 - val_mae: 0.1291 - learning_rate: 6.2500e-05

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# predict
y_pred_lstm = lstm.predict(X_test_seq)

# inverse scale FIRST (keep 2D shape)
y_pred_lstm = y_scaler.inverse_transform(y_pred_lstm)
y_test_actual = y_scaler.inverse_transform(y_test_seq)

# flatten for metrics
y_pred_lstm = y_pred_lstm.flatten()
y_test_actual = y_test_actual.flatten()

# metrics on real AQI values
mae_lstm = mean_absolute_error(y_test_actual, y_pred_lstm)
rmse_lstm = np.sqrt(mean_squared_error(y_test_actual, y_pred_lstm))

print("LSTM MAE:", mae_lstm)
print("LSTM RMSE:", rmse_lstm)
from sklearn.metrics import r2_score
r2= r2_score(y_test_actual, y_pred_lstm)
print("LSTM R2:", r2)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# LSTM MAE: 23.4590842637511
# LSTM RMSE: 32.71341201607788
# LSTM R2: 0.9623366133494412

# %%
epochs = range(1, len(history.history['mae']) + 1)

plt.figure(figsize=(8, 4))

plt.plot(epochs, history.history['mae'], label='Training MAE')
plt.plot(epochs, history.history['val_mae'], label='Validation MAE')

plt.xlabel('Epochs')
plt.ylabel('MAE (AQI units)')
plt.title('Training vs Validation MAE')
plt.legend()
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(12, 5))

# clip predictions to AQI range
y_pred_lstm = np.clip(y_pred_lstm, 0, 500)

# use correct length (same as plotted data)
n_samples = len(y_test_actual)
x_months = np.arange(n_samples) / 121.66

plt.plot(x_months, y_test_actual, label='Actual AQI', linewidth=2)
plt.plot(x_months, y_pred_lstm, label='Predicted AQI (LSTM)', linewidth=2)


# keep axis consistent with AQI definition
plt.ylim(0, 500)

plt.xlabel('Time (Months)')
plt.ylabel('AQI')
plt.title('Actual vs Predicted AQI (LSTM)')
plt.legend()
plt.grid(True)

plt.savefig("lstm_actual_vs_predicted.jpg", dpi=300, bbox_inches="tight")
plt.show()

# %%
df3=df2[['year', 'month', 'day', 'hour',
       'is_weekend','season', 'station', 'aqi']]

# %%
df3=df3.copy()

# %%
df3['aqi_lag_1']  = df3['aqi'].shift(1)   # 6 hours ago
df3['aqi_lag_2']  = df3['aqi'].shift(2)   # 12 hours ago
df3['aqi_lag_4']  = df3['aqi'].shift(4)   # 24 hours ago (daily cycle)
df3['aqi_lag_8']  = df3['aqi'].shift(8)   # 48 hours ago
df3['aqi_lag_28'] = df3['aqi'].shift(28)  # ~7 days

# %%
df3
# Out:
#         year  month  day  hour  is_weekend  season              station  aqi  \
# 0       2020      1    1     6           0  winter   Anand Vihar, Delhi  500
# 1       2020      1    1     6           0  winter   Mandir Marg, Delhi  399
# 2       2020      1    1     6           0  winter   NSIT Dwarka, Delhi  500
# 3       2020      1    1     6           0  winter        Noida Sec 125  500
# 4       2020      1    1     6           0  winter  Dwarka Sec 8, Delhi  473
# ...      ...    ...  ...   ...         ...     ...                  ...  ...
# 201659  2025     12   31    23           0  winter         Noida Sec 62  500
# 201660  2025     12   31    23           0  winter        Noida Sec 125  489
# 201661  2025     12   31    23           0  winter        Greater Noida  500
# 201662  2025     12   31    23           0  winter      Wazirpur, Delhi  500
# 201663  2025     12   31    23           0  winter       Ghaziabad Loni  500
#
#         aqi_lag_1  aqi_lag_2  aqi_lag_4  aqi_lag_8  aqi_lag_28
# 0             NaN        NaN        NaN        NaN         NaN
# 1           500.0        NaN        NaN        NaN         NaN
# 2           399.0      500.0        NaN        NaN         NaN
# 3           500.0      399.0        NaN        NaN         NaN
# 4           500.0      500.0      500.0        NaN         NaN
# ...           ...        ...        ...        ...         ...
# 201659      500.0      500.0      390.0      500.0       422.0
# 201660      500.0      500.0      500.0      405.0       500.0
# 201661      489.0      500.0      500.0      492.0       397.0
# 201662      500.0      489.0      500.0      500.0       436.0
# 201663      500.0      500.0      500.0      390.0       500.0
#
# [201664 rows x 13 columns]

# %%
df3=df3[df3['station'] == 'NSIT Dwarka, Delhi']
df3=df3.drop(columns=['station'])
df3
# Out:
#         year  month  day  hour  is_weekend  season  aqi  aqi_lag_1  aqi_lag_2  \
# 2       2020      1    1     6           0  winter  500      399.0      500.0
# 25      2020      1    1    12           0  winter  408      448.0      414.0
# 67      2020      1    1    18           0  winter  466      500.0      500.0
# 70      2020      1    1    23           0  winter  500      500.0      456.0
# 98      2020      1    2     6           0  winter  500      483.0      500.0
# ...      ...    ...  ...   ...         ...     ...  ...        ...        ...
# 201565  2025     12   30    23           0  winter  500      500.0      500.0
# 201578  2025     12   31     6           0  winter  500      500.0      500.0
# 201597  2025     12   31    12           0  winter  349      416.0      452.0
# 201627  2025     12   31    18           0  winter  426      415.0      476.0
# 201657  2025     12   31    23           0  winter  500      500.0      390.0
#
#         aqi_lag_4  aqi_lag_8  aqi_lag_28
# 2             NaN        NaN         NaN
# 25          500.0      500.0         NaN
# 67          500.0      500.0       500.0
# 70          500.0      500.0       500.0
# 98          500.0      444.0       500.0
# ...           ...        ...         ...
# 201565      500.0      500.0       440.0
# 201578      500.0      500.0       500.0
# 201597      500.0      500.0       500.0
# 201627      500.0      500.0       374.0
# 201657      492.0      500.0       500.0
#
# [8768 rows x 12 columns]

# %%
df3 = pd.get_dummies(df3, columns=['season'], drop_first=True)

# %%
df3=df3.apply(pd.to_numeric)
df3.dtypes
# Out:
# year                     int64
# month                    int64
# day                      int64
# hour                     int64
# is_weekend               int64
# aqi                      int64
# aqi_lag_1              float64
# aqi_lag_2              float64
# aqi_lag_4              float64
# aqi_lag_8              float64
# aqi_lag_28             float64
# season_post_monsoon       bool
# season_summer             bool
# season_winter             bool
# dtype: object

# %%
train_df = df3[df3['year'] < 2025]
test_df  = df3[df3['year'] == 2025]

drop_cols = ['aqi']

X_train = train_df.drop(columns=drop_cols)
y_train = train_df['aqi']

X_test = test_df.drop(columns=drop_cols)
y_test = test_df['aqi']

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

xgb = XGBRegressor(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='reg:squarederror',
    random_state=42,
    
)

xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_xgb = xgb.predict(X_test)

mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))

print("XGBoost MAE:", mae_xgb)
print("XGBoost RMSE:", rmse_xgb)
# Out:
# XGBoost MAE: 21.939495086669922
# XGBoost RMSE: 29.076291460529422

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
# Number of samples
n_samples = len(y_test)

# Convert samples to months (1 month = 120 samples)
x_months = np.arange(n_samples) / 121.66

plt.plot(x_months,y_test.values, label="Actual AQI", linewidth=2)
plt.plot(x_months,y_pred_xgb, label="Predicted AQI (XG)", linewidth=2)
plt.grid(True)
plt.legend()
plt.title("Actual vs Predicted AQI (XGBOOST Regression)")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert everything to numpy arrays
y_actual = np.array(y_test_actual)

y_xgb    = np.array(y_pred_xgb)
y_lstm   = np.array(y_pred_lstm)

# Find minimum length
min_len = min(len(y_actual), len(y_lstm), len(y_xgb))

# Align from the END (important for time series)
y_actual = y_actual[-min_len:]
y_lstm   = y_lstm[-min_len:]
y_xgb    = y_xgb[-min_len:]

# X-axis
x_months = np.arange(min_len) / 121.66

plt.figure(figsize=(12, 5))

plt.plot(x_months, y_actual, label='Actual AQI', linewidth=2)

plt.plot(x_months, y_xgb, label='Predicted AQI  (XGBoost)', linewidth=2)

plt.plot(x_months, y_lstm, label='Predicted TEMPORAL (LSTM)', linewidth=2)

plt.ylim(0, 500)
plt.xlabel('Time (Months)')
plt.ylabel('AQI')
plt.title('Actual vs Predicted AQI (2025)')
plt.legend()
plt.grid(True)
plt.savefig("LSTM vs XG BOOST.jpg", dpi=300, bbox_inches="tight")

plt.show()

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error 
import numpy as np

xgb = XGBRegressor(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='reg:squarederror',
    random_state=42,
    
)

xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_xgb = xgb.predict(X_test)

mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))

print("XGBoost MAE:", mae_xgb)
print("XGBoost RMSE:", rmse_xgb)
from sklearn.metrics import r2_score

r2_xgb = r2_score(y_test, y_pred_xgb)
print("XGBoost R2:", r2_xgb)
# Out:
# XGBoost MAE: 21.939495086669922
# XGBoost RMSE: 29.076291460529422
# XGBoost R2: 0.9702720046043396
