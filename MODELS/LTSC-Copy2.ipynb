# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import os, random, numpy as np, tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)
os.environ['PYTHONHASHSEED'] = '42'

# %%
df=pd.read_csv("C:/Users/Dhruv/Onedrive/Desktop/samsung/aqi/delhi_ncr_aqi_dataset.csv")
df
# Out:
#                    datetime        date  year  month  day  hour day_of_week  \
# 0       2020-01-01 06:00:00  2020-01-01  2020      1    1     6   Wednesday
# 1       2020-01-01 12:00:00  2020-01-01  2020      1    1    12   Wednesday
# 2       2020-01-01 18:00:00  2020-01-01  2020      1    1    18   Wednesday
# 3       2020-01-01 23:00:00  2020-01-01  2020      1    1    23   Wednesday
# 4       2020-01-01 06:00:00  2020-01-01  2020      1    1     6   Wednesday
# ...                     ...         ...   ...    ...  ...   ...         ...
# 201659  2025-12-31 23:00:00  2025-12-31  2025     12   31    23   Wednesday
# 201660  2025-12-31 06:00:00  2025-12-31  2025     12   31     6   Wednesday
# 201661  2025-12-31 12:00:00  2025-12-31  2025     12   31    12   Wednesday
# 201662  2025-12-31 18:00:00  2025-12-31  2025     12   31    18   Wednesday
# 201663  2025-12-31 23:00:00  2025-12-31  2025     12   31    23   Wednesday
#
#         is_weekend  season       city  ...    no2   so2    co    o3  \
# 0                0  winter      Delhi  ...  119.6  47.7  5.19  12.3
# 1                0  winter      Delhi  ...  117.9  39.3  4.32  15.8
# 2                0  winter      Delhi  ...  150.1  36.3  7.13  14.3
# 3                0  winter      Delhi  ...  142.0  30.3  4.90  13.2
# 4                0  winter      Delhi  ...  138.4  41.5  7.56  15.4
# ...            ...     ...        ...  ...    ...   ...   ...   ...
# 201659           0  winter  Ghaziabad  ...   97.0  23.9  5.58  14.8
# 201660           0  winter  Ghaziabad  ...  119.2  26.9  5.34  12.1
# 201661           0  winter  Ghaziabad  ...   90.3  33.7  3.73  28.2
# 201662           0  winter  Ghaziabad  ...  170.7  20.9  6.98  22.9
# 201663           0  winter  Ghaziabad  ...   89.0  27.5  5.17  17.6
#
#         temperature  humidity  wind_speed  visibility  aqi  aqi_category
# 0               9.4       100         3.6         1.2  500        Severe
# 1              20.6        50         5.9         1.4  500        Severe
# 2              12.4        56         4.5         1.1  500        Severe
# 3              14.4        48         5.8         1.4  500        Severe
# 4               6.8       100         2.8         0.4  500        Severe
# ...             ...       ...         ...         ...  ...           ...
# 201659         16.1        51         3.8         0.9  500        Severe
# 201660          9.8        95         3.2         1.2  500        Severe
# 201661         21.4        57         7.1         2.9  500        Severe
# 201662         15.4        51         6.8         1.2  500        Severe
# 201663         17.3        46         5.4         1.0  500        Severe
#
# [201664 rows x 25 columns]

# %%
df['station'].unique()
# Out:
# array(['Anand Vihar, Delhi', 'Jahangirpuri, Delhi', 'Wazirpur, Delhi',
#        'Bawana, Delhi', 'ITO, Delhi', 'Punjabi Bagh, Delhi',
#        'Okhla Phase 2, Delhi', 'Shadipur, Delhi', 'Rohini, Delhi',
#        'RK Puram, Delhi', 'Siri Fort, Delhi', 'Dwarka Sec 8, Delhi',
#        'NSIT Dwarka, Delhi', 'Mandir Marg, Delhi', 'Noida Sec 62',
#        'Noida Sec 125', 'Greater Noida', 'Gurugram Vikas Sadan',
#        'Gurugram Sec 51', 'Faridabad Sec 16A', 'Faridabad New Town',
#        'Ghaziabad Vasundhara', 'Ghaziabad Loni'], dtype=object)

# %%
df.columns
# Out:
# Index(['datetime', 'date', 'year', 'month', 'day', 'hour', 'day_of_week',
#        'is_weekend', 'season', 'city', 'station', 'latitude', 'longitude',
#        'pm25', 'pm10', 'no2', 'so2', 'co', 'o3', 'temperature', 'humidity',
#        'wind_speed', 'visibility', 'aqi', 'aqi_category'],
#       dtype='object')

# %%
df = df.sort_values('datetime').reset_index(drop=True)
df2=df.copy()

# %%
df=df[['year', 'month', 'day', 'hour',
       'is_weekend','season', 'station', 'aqi']]

# %%
df
# Out:
#         year  month  day  hour  is_weekend  season              station  aqi
# 0       2020      1    1     6           0  winter   Anand Vihar, Delhi  500
# 1       2020      1    1     6           0  winter   Mandir Marg, Delhi  399
# 2       2020      1    1     6           0  winter   NSIT Dwarka, Delhi  500
# 3       2020      1    1     6           0  winter        Noida Sec 125  500
# 4       2020      1    1     6           0  winter  Dwarka Sec 8, Delhi  473
# ...      ...    ...  ...   ...         ...     ...                  ...  ...
# 201659  2025     12   31    23           0  winter         Noida Sec 62  500
# 201660  2025     12   31    23           0  winter        Noida Sec 125  489
# 201661  2025     12   31    23           0  winter        Greater Noida  500
# 201662  2025     12   31    23           0  winter      Wazirpur, Delhi  500
# 201663  2025     12   31    23           0  winter       Ghaziabad Loni  500
#
# [201664 rows x 8 columns]

# %%
df['station'].unique()
# Out:
# array(['Anand Vihar, Delhi', 'Mandir Marg, Delhi', 'NSIT Dwarka, Delhi',
#        'Noida Sec 125', 'Dwarka Sec 8, Delhi', 'Greater Noida',
#        'Siri Fort, Delhi', 'RK Puram, Delhi', 'Gurugram Vikas Sadan',
#        'Rohini, Delhi', 'Gurugram Sec 51', 'Shadipur, Delhi',
#        'Okhla Phase 2, Delhi', 'Faridabad Sec 16A', 'Punjabi Bagh, Delhi',
#        'Faridabad New Town', 'Noida Sec 62', 'Wazirpur, Delhi',
#        'Ghaziabad Loni', 'Ghaziabad Vasundhara', 'ITO, Delhi',
#        'Bawana, Delhi', 'Jahangirpuri, Delhi'], dtype=object)

# %%
df1=df[df['station'] == 'NSIT Dwarka, Delhi']
df1=df1.drop(columns=['station'])
df1
# Out:
#         year  month  day  hour  is_weekend  season  aqi
# 2       2020      1    1     6           0  winter  500
# 25      2020      1    1    12           0  winter  408
# 67      2020      1    1    18           0  winter  466
# 70      2020      1    1    23           0  winter  500
# 98      2020      1    2     6           0  winter  500
# ...      ...    ...  ...   ...         ...     ...  ...
# 201565  2025     12   30    23           0  winter  500
# 201578  2025     12   31     6           0  winter  500
# 201597  2025     12   31    12           0  winter  349
# 201627  2025     12   31    18           0  winter  426
# 201657  2025     12   31    23           0  winter  500
#
# [8768 rows x 7 columns]

# %%
df1['season'].unique()
# Out:
# array(['winter', 'summer', 'monsoon', 'post_monsoon'], dtype=object)

# %%
df1 = pd.get_dummies(df1, columns=['season'], drop_first=True)

# %%
df1
# Out:
#         year  month  day  hour  is_weekend  aqi  season_post_monsoon  \
# 2       2020      1    1     6           0  500                False
# 25      2020      1    1    12           0  408                False
# 67      2020      1    1    18           0  466                False
# 70      2020      1    1    23           0  500                False
# 98      2020      1    2     6           0  500                False
# ...      ...    ...  ...   ...         ...  ...                  ...
# 201565  2025     12   30    23           0  500                False
# 201578  2025     12   31     6           0  500                False
# 201597  2025     12   31    12           0  349                False
# 201627  2025     12   31    18           0  426                False
# 201657  2025     12   31    23           0  500                False
#
#         season_summer  season_winter
# 2               False           True
# 25              False           True
# 67              False           True
# 70              False           True
# 98              False           True
# ...               ...            ...
# 201565          False           True
# 201578          False           True
# 201597          False           True
# 201627          False           True
# 201657          False           True
#
# [8768 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# year          0
# month         0
# day           0
# hour          0
# is_weekend    0
# season        0
# station       0
# aqi           0
# dtype: int64

# %%
df1 = df1.dropna().reset_index(drop=True)

# %%
df1
# Out:
#       year  month  day  hour  is_weekend  aqi  season_post_monsoon  \
# 0     2020      1    1     6           0  500                False
# 1     2020      1    1    12           0  408                False
# 2     2020      1    1    18           0  466                False
# 3     2020      1    1    23           0  500                False
# 4     2020      1    2     6           0  500                False
# ...    ...    ...  ...   ...         ...  ...                  ...
# 8763  2025     12   30    23           0  500                False
# 8764  2025     12   31     6           0  500                False
# 8765  2025     12   31    12           0  349                False
# 8766  2025     12   31    18           0  426                False
# 8767  2025     12   31    23           0  500                False
#
#       season_summer  season_winter
# 0             False           True
# 1             False           True
# 2             False           True
# 3             False           True
# 4             False           True
# ...             ...            ...
# 8763          False           True
# 8764          False           True
# 8765          False           True
# 8766          False           True
# 8767          False           True
#
# [8768 rows x 9 columns]

# %%
df1.columns
# Out:
# Index(['year', 'month', 'day', 'hour', 'is_weekend', 'aqi',
#        'season_post_monsoon', 'season_summer', 'season_winter'],
#       dtype='object')

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# sort by time
lstm_df = df1.sort_values(['year','month','day','hour']).reset_index(drop=True)

feature_cols = [
    'year', 'month', 'day',             # past AQI used as input
    'hour', 'is_weekend',
    'season_winter', 'season_summer', 'season_post_monsoon'
]

# -----------------------------
# TRAIN / TEST SPLIT
# -----------------------------
train_df = lstm_df[lstm_df['year'] < 2025]
test_df  = lstm_df[lstm_df['year'] == 2025]

X_train = train_df[feature_cols].values
X_test  = test_df[feature_cols].values

y_train = train_df['aqi'].values.reshape(-1,1)
y_test  = test_df['aqi'].values.reshape(-1,1)

# -----------------------------
# SCALING (fit ONLY on train)
# -----------------------------
X_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train = X_scaler.fit_transform(X_train)
X_test  = X_scaler.transform(X_test)

y_train = y_scaler.fit_transform(y_train)
y_test  = y_scaler.transform(y_test)

# -----------------------------
# CREATE SEQUENCES
# -----------------------------
TIMESTEPS = 24  # 1 day window

def create_sequences(X, y, t):
    X_seq, y_seq = [], []
    for i in range(len(X) - t):
        X_seq.append(X[i:i+t])
        y_seq.append(y[i+t])
    return np.array(X_seq), np.array(y_seq)

X_train_seq, y_train_seq = create_sequences(X_train, y_train, TIMESTEPS)
X_test_seq,  y_test_seq  = create_sequences(X_test,  y_test,  TIMESTEPS)

# %%
lstm_df
# Out:
#       year  month  day  hour  is_weekend  aqi  season_post_monsoon  \
# 0     2020      1    1     6           0  500                False
# 1     2020      1    1    12           0  408                False
# 2     2020      1    1    18           0  466                False
# 3     2020      1    1    23           0  500                False
# 4     2020      1    2     6           0  500                False
# ...    ...    ...  ...   ...         ...  ...                  ...
# 8763  2025     12   30    23           0  500                False
# 8764  2025     12   31     6           0  500                False
# 8765  2025     12   31    12           0  349                False
# 8766  2025     12   31    18           0  426                False
# 8767  2025     12   31    23           0  500                False
#
#       season_summer  season_winter
# 0             False           True
# 1             False           True
# 2             False           True
# 3             False           True
# 4             False           True
# ...             ...            ...
# 8763          False           True
# 8764          False           True
# 8765          False           True
# 8766          False           True
# 8767          False           True
#
# [8768 rows x 9 columns]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

lstm = Sequential()
lstm.add(LSTM(64, input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])))
lstm.add(Dense(1))

lstm.compile(
    optimizer='adam',
    loss='mae',
    metrics=['mae']
)

lstm.summary()
# Out:
# C:\Users\Dhruv\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          18,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,753 (73.25 KB)
#  Trainable params: 18,753 (73.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(
    monitor='val_mae',
    patience=15,        
    min_delta=0.0015,     
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_mae',
    factor=0.5,
    patience=6,
    min_lr=1e-5,
    verbose=1
)

history = lstm.fit(
    X_train_seq,
    y_train_seq,
    epochs=120,         
    batch_size=32,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.4487 - mae: 0.4487 - val_loss: 0.3610 - val_mae: 0.3610 - learning_rate: 0.0010
# Epoch 2/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2665 - mae: 0.2665 - val_loss: 0.2677 - val_mae: 0.2677 - learning_rate: 0.0010
# Epoch 3/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.2649 - mae: 0.2649 - val_loss: 0.2650 - val_mae: 0.2650 - learning_rate: 0.0010
# Epoch 4/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2507 - mae: 0.2507 - val_loss: 0.2625 - val_mae: 0.2625 - learning_rate: 0.0010
# Epoch 5/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.2378 - mae: 0.2378 - val_loss: 0.2178 - val_mae: 0.2178 - learning_rate: 0.0010
# Epoch 6/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.2206 - mae: 0.2206 - val_loss: 0.3011 - val_mae: 0.3011 - learning_rate: 0.0010
# Epoch 7/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2317 - mae: 0.2317 - val_loss: 0.2556 - val_mae: 0.2556 - learning_rate: 0.0010
# Epoch 8/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.2220 - mae: 0.2220 - val_loss: 0.2248 - val_mae: 0.2248 - learning_rate: 0.0010
# Epoch 9/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.2298 - mae: 0.2298 - val_loss: 0.2054 - val_mae: 0.2054 - learning_rate: 0.0010
# Epoch 10/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.1997 - mae: 0.1997 - val_loss: 0.2135 - val_mae: 0.2135 - learning_rate: 0.0010
# Epoch 11/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2044 - mae: 0.2044 - val_loss: 0.3171 - val_mae: 0.3171 - learning_rate: 0.0010
# Epoch 12/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.2122 - mae: 0.2122 - val_loss: 0.2695 - val_mae: 0.2695 - learning_rate: 0.0010
# Epoch 13/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.2220 - mae: 0.2220 - val_loss: 0.2088 - val_mae: 0.2088 - learning_rate: 0.0010
# Epoch 14/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.2031 - mae: 0.2031 - val_loss: 0.2194 - val_mae: 0.2194 - learning_rate: 0.0010
# Epoch 15/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.1955 - mae: 0.1955 - val_loss: 0.1701 - val_mae: 0.1701 - learning_rate: 0.0010
# Epoch 16/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2020 - mae: 0.2020 - val_loss: 0.2453 - val_mae: 0.2453 - learning_rate: 0.0010
# Epoch 17/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.1796 - mae: 0.1796 - val_loss: 0.2285 - val_mae: 0.2285 - learning_rate: 0.0010
# Epoch 18/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.1867 - mae: 0.1867 - val_loss: 0.1802 - val_mae: 0.1802 - learning_rate: 0.0010
# Epoch 19/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.2017 - mae: 0.2017 - val_loss: 0.2599 - val_mae: 0.2599 - learning_rate: 0.0010
# Epoch 20/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1877 - mae: 0.1877 - val_loss: 0.1682 - val_mae: 0.1682 - learning_rate: 0.0010
# Epoch 21/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.1916 - mae: 0.1916 - val_loss: 0.1740 - val_mae: 0.1740 - learning_rate: 0.0010
# Epoch 22/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1781 - mae: 0.1781 - val_loss: 0.2255 - val_mae: 0.2255 - learning_rate: 0.0010
# Epoch 23/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.1904 - mae: 0.1904 - val_loss: 0.1986 - val_mae: 0.1986 - learning_rate: 0.0010
# Epoch 24/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.1734 - mae: 0.1734 - val_loss: 0.1763 - val_mae: 0.1763 - learning_rate: 0.0010
# Epoch 25/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.1858 - mae: 0.1858 - val_loss: 0.2258 - val_mae: 0.2258 - learning_rate: 0.0010
# Epoch 26/120
# 179/183 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1741 - mae: 0.1741
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.1708 - mae: 0.1708 - val_loss: 0.2646 - val_mae: 0.2646 - learning_rate: 0.0010
# Epoch 27/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.1765 - mae: 0.1765 - val_loss: 0.1629 - val_mae: 0.1629 - learning_rate: 5.0000e-04
# Epoch 28/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1644 - mae: 0.1644 - val_loss: 0.1561 - val_mae: 0.1561 - learning_rate: 5.0000e-04
# Epoch 29/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.1535 - mae: 0.1535 - val_loss: 0.1525 - val_mae: 0.1525 - learning_rate: 5.0000e-04
# Epoch 30/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1476 - mae: 0.1476 - val_loss: 0.1792 - val_mae: 0.1792 - learning_rate: 5.0000e-04
# Epoch 31/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1613 - mae: 0.1613 - val_loss: 0.1601 - val_mae: 0.1601 - learning_rate: 5.0000e-04
# Epoch 32/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1518 - mae: 0.1518 - val_loss: 0.1555 - val_mae: 0.1555 - learning_rate: 5.0000e-04
# Epoch 33/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.1518 - mae: 0.1518 - val_loss: 0.1631 - val_mae: 0.1631 - learning_rate: 5.0000e-04
# Epoch 34/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1482 - mae: 0.1482 - val_loss: 0.1609 - val_mae: 0.1609 - learning_rate: 5.0000e-04
# Epoch 35/120
# 182/183 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1757 - mae: 0.1757
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1584 - mae: 0.1584 - val_loss: 0.1548 - val_mae: 0.1548 - learning_rate: 5.0000e-04
# Epoch 36/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1386 - mae: 0.1386 - val_loss: 0.1440 - val_mae: 0.1440 - learning_rate: 2.5000e-04
# Epoch 37/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.1376 - mae: 0.1376 - val_loss: 0.1427 - val_mae: 0.1427 - learning_rate: 2.5000e-04
# Epoch 38/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1341 - mae: 0.1341 - val_loss: 0.1505 - val_mae: 0.1505 - learning_rate: 2.5000e-04
# Epoch 39/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1352 - mae: 0.1352 - val_loss: 0.1591 - val_mae: 0.1591 - learning_rate: 2.5000e-04
# Epoch 40/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1315 - mae: 0.1315 - val_loss: 0.1470 - val_mae: 0.1470 - learning_rate: 2.5000e-04
# Epoch 41/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1342 - mae: 0.1342 - val_loss: 0.1432 - val_mae: 0.1432 - learning_rate: 2.5000e-04
# Epoch 42/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.1353 - mae: 0.1353 - val_loss: 0.1401 - val_mae: 0.1401 - learning_rate: 2.5000e-04
# Epoch 43/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1332 - mae: 0.1332 - val_loss: 0.1471 - val_mae: 0.1471 - learning_rate: 2.5000e-04
# Epoch 44/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1350 - mae: 0.1350 - val_loss: 0.1468 - val_mae: 0.1468 - learning_rate: 2.5000e-04
# Epoch 45/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1302 - mae: 0.1302 - val_loss: 0.1420 - val_mae: 0.1420 - learning_rate: 2.5000e-04
# Epoch 46/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1304 - mae: 0.1304 - val_loss: 0.1436 - val_mae: 0.1436 - learning_rate: 2.5000e-04
# Epoch 47/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1354 - mae: 0.1354 - val_loss: 0.1500 - val_mae: 0.1500 - learning_rate: 2.5000e-04
# Epoch 48/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1381 - mae: 0.1381
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1331 - mae: 0.1331 - val_loss: 0.1475 - val_mae: 0.1475 - learning_rate: 2.5000e-04
# Epoch 49/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1289 - mae: 0.1289 - val_loss: 0.1401 - val_mae: 0.1401 - learning_rate: 1.2500e-04
# Epoch 50/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1268 - mae: 0.1268 - val_loss: 0.1393 - val_mae: 0.1393 - learning_rate: 1.2500e-04
# Epoch 51/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1263 - mae: 0.1263 - val_loss: 0.1412 - val_mae: 0.1412 - learning_rate: 1.2500e-04
# Epoch 52/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1266 - mae: 0.1266 - val_loss: 0.1419 - val_mae: 0.1419 - learning_rate: 1.2500e-04
# Epoch 53/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1258 - mae: 0.1258 - val_loss: 0.1407 - val_mae: 0.1407 - learning_rate: 1.2500e-04
# Epoch 54/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1253 - mae: 0.1253 - val_loss: 0.1393 - val_mae: 0.1393 - learning_rate: 1.2500e-04
# Epoch 55/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.1253 - mae: 0.1253 - val_loss: 0.1397 - val_mae: 0.1397 - learning_rate: 1.2500e-04
# Epoch 56/120
# 180/183 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1299 - mae: 0.1299
# Epoch 56: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.1255 - mae: 0.1255 - val_loss: 0.1429 - val_mae: 0.1429 - learning_rate: 1.2500e-04
# Epoch 57/120
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1244 - mae: 0.1244 - val_loss: 0.1393 - val_mae: 0.1393 - learning_rate: 6.2500e-05

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# predict
y_pred_lstm = lstm.predict(X_test_seq)

# inverse scale FIRST (keep 2D shape)
y_pred_lstm = y_scaler.inverse_transform(y_pred_lstm)
y_test_actual = y_scaler.inverse_transform(y_test_seq)

# flatten for metrics
y_pred_lstm = y_pred_lstm.flatten()
y_test_actual = y_test_actual.flatten()

# metrics on real AQI values
mae_lstm = mean_absolute_error(y_test_actual, y_pred_lstm)
rmse_lstm = np.sqrt(mean_squared_error(y_test_actual, y_pred_lstm))

print("LSTM MAE:", mae_lstm)
print("LSTM RMSE:", rmse_lstm)
from sklearn.metrics import r2_score
r2= r2_score(y_test_actual, y_pred_lstm)
print("LSTM R2:", r2)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# LSTM MAE: 26.088740574616242
# LSTM RMSE: 37.29133172490753
# LSTM R2: 0.9510578022431716

# %%
epochs = range(1, len(history.history['mae']) + 1)

plt.figure(figsize=(8, 4))

plt.plot(epochs, history.history['mae'], label='Training MAE')
plt.plot(epochs, history.history['val_mae'], label='Validation MAE')

plt.xlabel('Epochs')
plt.ylabel('MAE (AQI units)')
plt.title('Training vs Validation MAE')
plt.legend()
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(12, 5))

# clip predictions to AQI range
y_pred_lstm = np.clip(y_pred_lstm, 0, 500)

# use correct length (same as plotted data)
n_samples = len(y_test_actual)
x_months = np.arange(n_samples) / 121.66

plt.plot(x_months, y_test_actual, label='Actual AQI', linewidth=2)
plt.plot(x_months, y_pred_lstm, label='Predicted AQI (LSTM)', linewidth=2)


# keep axis consistent with AQI definition
plt.ylim(0, 500)

plt.xlabel('Time (Months)')
plt.ylabel('AQI')
plt.title('Actual vs Predicted AQI (LSTM)')
plt.legend()
plt.grid(True)

plt.savefig("lstm_actual_vs_predicted.jpg", dpi=300, bbox_inches="tight")
plt.show()

# %%
df3=df2[['year', 'month', 'day', 'hour',
       'is_weekend','season', 'station','pm25', 'pm10', 'no2', 'so2', 'co', 'o3', 'temperature', 'humidity',
       'wind_speed', 'visibility',  'aqi']]

# %%
df3=df3.copy()

# %%
df3['aqi_lag_1']  = df3['aqi'].shift(1)   # 6 hours ago
df3['aqi_lag_2']  = df3['aqi'].shift(2)   # 12 hours ago
df3['aqi_lag_4']  = df3['aqi'].shift(4)   # 24 hours ago (daily cycle)
df3['aqi_lag_8']  = df3['aqi'].shift(8)   # 48 hours ago
df3['aqi_lag_28'] = df3['aqi'].shift(28)  # ~7 days

# %%
df3
# Out:
#         year  month  day  hour  is_weekend  season              station  \
# 0       2020      1    1     6           0  winter   Anand Vihar, Delhi
# 1       2020      1    1     6           0  winter   Mandir Marg, Delhi
# 2       2020      1    1     6           0  winter   NSIT Dwarka, Delhi
# 3       2020      1    1     6           0  winter        Noida Sec 125
# 4       2020      1    1     6           0  winter  Dwarka Sec 8, Delhi
# ...      ...    ...  ...   ...         ...     ...                  ...
# 201659  2025     12   31    23           0  winter         Noida Sec 62
# 201660  2025     12   31    23           0  winter        Noida Sec 125
# 201661  2025     12   31    23           0  winter        Greater Noida
# 201662  2025     12   31    23           0  winter      Wazirpur, Delhi
# 201663  2025     12   31    23           0  winter       Ghaziabad Loni
#
#          pm25   pm10    no2  ...  temperature  humidity  wind_speed  \
# 0       371.8  739.4  119.6  ...          9.4       100         3.6
# 1       248.2  424.5   94.7  ...          8.3       100         3.6
# 2       327.0  596.1  111.2  ...          9.9       100         2.2
# 3       266.3  572.8   86.0  ...          9.4       100         3.5
# 4       269.8  488.6   89.8  ...          7.4       100         3.4
# ...       ...    ...    ...  ...          ...       ...         ...
# 201659  340.1  600.4  138.7  ...         14.8        48         6.8
# 201660  249.2  501.2   93.0  ...         15.7        51         6.2
# 201661  264.0  568.9   92.2  ...         16.0        54         4.3
# 201662  440.1  816.5  167.1  ...         17.7        64         6.5
# 201663  304.1  536.0   89.0  ...         17.3        46         5.4
#
#         visibility  aqi  aqi_lag_1  aqi_lag_2  aqi_lag_4  aqi_lag_8  \
# 0              1.2  500        NaN        NaN        NaN        NaN
# 1              1.7  399      500.0        NaN        NaN        NaN
# 2              1.3  500      399.0      500.0        NaN        NaN
# 3              2.9  500      500.0      399.0        NaN        NaN
# 4              2.6  473      500.0      500.0      500.0        NaN
# ...            ...  ...        ...        ...        ...        ...
# 201659         0.8  500      500.0      500.0      390.0      500.0
# 201660         2.3  489      500.0      500.0      500.0      405.0
# 201661         2.7  500      489.0      500.0      500.0      492.0
# 201662         1.0  500      500.0      489.0      500.0      500.0
# 201663         1.0  500      500.0      500.0      500.0      390.0
#
#         aqi_lag_28
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 201659       422.0
# 201660       500.0
# 201661       397.0
# 201662       436.0
# 201663       500.0
#
# [201664 rows x 23 columns]

# %%
df3=df3[df3['station'] == 'NSIT Dwarka, Delhi']
df3=df3.drop(columns=['station'])
df3
# Out:
#         year  month  day  hour  is_weekend  season   pm25   pm10    no2   so2  \
# 2       2020      1    1     6           0  winter  327.0  596.1  111.2  22.6
# 25      2020      1    1    12           0  winter  231.1  436.6   95.0  18.3
# 67      2020      1    1    18           0  winter  271.6  483.2  128.4  25.2
# 70      2020      1    1    23           0  winter  324.8  655.0  104.1  27.3
# 98      2020      1    2     6           0  winter  350.2  636.3  125.5  20.4
# ...      ...    ...  ...   ...         ...     ...    ...    ...    ...   ...
# 201565  2025     12   30    23           0  winter  272.5  574.7  107.4  25.9
# 201578  2025     12   31     6           0  winter  308.5  666.1   88.9  29.1
# 201597  2025     12   31    12           0  winter  183.5  369.0   59.3  18.2
# 201627  2025     12   31    18           0  winter  260.0  450.7  147.3  21.2
# 201657  2025     12   31    23           0  winter  279.5  536.3   95.7  16.5
#
#         ...  temperature  humidity  wind_speed  visibility  aqi  aqi_lag_1  \
# 2       ...          9.9       100         2.2         1.3  500      399.0
# 25      ...         17.2        46         9.9         2.6  408      448.0
# 67      ...         14.1        64         6.6         2.5  466      500.0
# 70      ...         12.5        45         4.4         0.7  500      500.0
# 98      ...          6.3       100         2.4         0.8  500      483.0
# ...     ...          ...       ...         ...         ...  ...        ...
# 201565  ...         14.3        49         6.8         2.9  500      500.0
# 201578  ...          8.2       100         2.5         0.8  500      500.0
# 201597  ...         21.3        63         8.8         3.1  349      416.0
# 201627  ...         16.4        61         5.9         2.9  426      415.0
# 201657  ...         17.5        53         7.0         1.1  500      500.0
#
#         aqi_lag_2  aqi_lag_4  aqi_lag_8  aqi_lag_28
# 2           500.0        NaN        NaN         NaN
# 25          414.0      500.0      500.0         NaN
# 67          500.0      500.0      500.0       500.0
# 70          456.0      500.0      500.0       500.0
# 98          500.0      500.0      444.0       500.0
# ...           ...        ...        ...         ...
# 201565      500.0      500.0      500.0       440.0
# 201578      500.0      500.0      500.0       500.0
# 201597      452.0      500.0      500.0       500.0
# 201627      476.0      500.0      500.0       374.0
# 201657      390.0      492.0      500.0       500.0
#
# [8768 rows x 22 columns]

# %%
df3 = pd.get_dummies(df3, columns=['season'], drop_first=True)

# %%
df3=df3.apply(pd.to_numeric)
df3.dtypes
# Out:
# year                     int64
# month                    int64
# day                      int64
# hour                     int64
# is_weekend               int64
# pm25                   float64
# pm10                   float64
# no2                    float64
# so2                    float64
# co                     float64
# o3                     float64
# temperature            float64
# humidity                 int64
# wind_speed             float64
# visibility             float64
# aqi                      int64
# aqi_lag_1              float64
# aqi_lag_2              float64
# aqi_lag_4              float64
# aqi_lag_8              float64
# aqi_lag_28             float64
# season_post_monsoon       bool
# season_summer             bool
# season_winter             bool
# dtype: object

# %%
train_df = df3[df3['year'] < 2025]
test_df  = df3[df3['year'] == 2025]

drop_cols = ['aqi']

X_train = train_df.drop(columns=drop_cols)
y_train = train_df['aqi']

X_test = test_df.drop(columns=drop_cols)
y_test = test_df['aqi']

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

xgb = XGBRegressor(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='reg:squarederror',
    random_state=42,
    
)

xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_xgb = xgb.predict(X_test)

mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))

print("XGBoost MAE:", mae_xgb)
print("XGBoost RMSE:", rmse_xgb)
# Out:
# XGBoost MAE: 0.8842124342918396
# XGBoost RMSE: 1.3960125319429393

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
# Number of samples
n_samples = len(y_test)

# Convert samples to months (1 month = 120 samples)
x_months = np.arange(n_samples) / 121.66

plt.plot(x_months,y_test.values, label="Actual AQI", linewidth=2)
plt.plot(x_months,y_pred_xgb, label="Predicted AQI (MLR)", linewidth=2)
plt.grid(True)
plt.legend()
plt.title("Actual vs Predicted AQI (XGBOOST Regression)")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert everything to numpy arrays
y_actual = np.array(y_test_actual)

y_xgb    = np.array(y_pred_xgb)
y_lstm   = np.array(y_pred_lstm)

# Find minimum length
min_len = min(len(y_actual), len(y_lstm), len(y_xgb))

# Align from the END (important for time series)
y_actual = y_actual[-min_len:]
y_lstm   = y_lstm[-min_len:]
y_xgb    = y_xgb[-min_len:]

# X-axis
x_months = np.arange(min_len) / 121.66

plt.figure(figsize=(12, 5))

plt.plot(x_months, y_actual, label='Actual AQI', linewidth=2)

plt.plot(x_months, y_xgb, label='Predicted AQI POLLUTANS (XGBoost)', linewidth=2)

plt.plot(x_months, y_lstm, label='Predicted TEMPORAL (LSTM)', linewidth=2)

plt.ylim(0, 500)
plt.xlabel('Time (Months)')
plt.ylabel('AQI')
plt.title('Actual vs Predicted AQI (2025)')
plt.legend()
plt.grid(True)

plt.show()

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

xgb = XGBRegressor(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='reg:squarederror',
    random_state=42,
    
)

xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=None, num_parallel_tree=None, ...)
